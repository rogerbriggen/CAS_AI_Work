# %% [markdown]
# # Eigene Probe-Klausur - ertsellt von 3 Teams **100 Punkte**
#
# ---
#
#
#
# ---

# %% [markdown]
# ## 1 - Team 1 - Dense Network Params **50 Punkte**
#
#
# ---

# %%
import torch
import numpy as np
from torch import nn
import matplotlib.pyplot as plt
import pandas as pd
from torch.utils.data import TensorDataset, DataLoader, Dataset
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Aufgabe 1

# %% [markdown]
# ## Aufgabe 1.1

# %%
# Matrizenarithmetik
# Vervollständige die fehlenden Werte
# a)
x_1 = #
x_2 = #

a = torch.randn(x_1, 3)
b = torch.randn(4, x_2)
c = a + b
assert c.size() == (4,3)

x_3 = #
x_4 = #

b = c - a
assert b.size() == (x_3, x_4)

# b)
x_5 = #
x_6 = #

a = torch.randn(5, 4)
b = torch.randn(x_5, 4)
c = a * b
assert c.size() == (x_6, 4)

# %% [markdown]
# ## Lösung

# %%
# Matrizenarithmetik
# Vervollständige die fehlenden Werte
# a)
x_1 = 4 #
x_2 = 3 #

a = torch.randn(x_1, 3)
b = torch.randn(4, x_2)
c = a + b
assert c.size() == (4,3)

x_3 = 4 #
x_4 = 3 #

b = c - a
assert b.size() == (x_3, x_4)

# b)
x_5 = 5 #
x_6 = 5 #

a = torch.randn(5, 4)
b = torch.randn(x_5, 4)
c = a * b
assert c.size() == (x_6, 4)

# %% [markdown]
# ## Aufgabe 1.2

# %%
# Initialisierung des Vektors v und der Matrix M
v = torch.randn(3, dtype=torch.float)
M = torch.randn(3, 2, dtype=torch.float)
b = torch.randn(2, dtype=torch.float)

#Berechne das Produkt der transponierten Matrix M.T und des Vektors v.
y = _____ -> #torch.matmul(M.T, v)  # M.T ist die Transponierte von M, um das Matrix-Vektor-Produkt zu berechnen

#Addiere den bias-Vektor b zum Ergebis des Matrix-Vektor Produkts
y_with_bias = _____# y + b  # bias
# Ausgabe der Ergebnisse
print("Matrix-Vektor-Produkt:\n", y)
print("Matrix-Vektor-Produkt mit Bias:\n", y_with_bias)

# %% [markdown]
# ## Lösung

# %%
# Initialisierung des Vektors v und der Matrix M
v = torch.randn(3, dtype=torch.float)
M = torch.randn(3, 2, dtype=torch.float)
b = torch.randn(2, dtype=torch.float)

#Berechne das Produkt der transponierten Matrix M.T und des Vektors v.
#y = __(2,)___ -> #torch.matmul(M.T, v)  # M.T ist die Transponierte von M, um das Matrix-Vektor-Produkt zu berechnen
y = torch.matmul(M.T, v)

#Addiere den bias-Vektor b zum Ergebis des Matrix-Vektor Produkts
#y_with_bias = __(2,)___# y + b  # bias
y_with_bias = y + b
# Ausgabe der Ergebnisse
print("Matrix-Vektor-Produkt:\n", y)  # (2,)
print("Matrix-Vektor-Produkt mit Bias:\n", y_with_bias)  # (2,)

# Show the shape instead of the value
print("Matrix-Vektor-Produkt:\n", y.shape)  # (2,)
print("Matrix-Vektor-Produkt mit Bias:\n", y_with_bias.shape)  # (2,)
# Out:
# Matrix-Vektor-Produkt:
#  tensor([-0.5921,  0.7024])
# Matrix-Vektor-Produkt mit Bias:
#  tensor([-0.2495,  1.2604])
# Matrix-Vektor-Produkt:
#  torch.Size([2])
# Matrix-Vektor-Produkt mit Bias:
#  torch.Size([2])

# %% [markdown]
# ## Aufgabe 1.3

# %%
# Gib einen sinnvollen und erlaubten Wert bei "xxxx" ein und erkläre, wie der Wert das Resultat beinflusst.

class DQN(nn.Module):
    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 512)
        self.layer3 = NoisyLinear(512, n_actions, sigma_init=xxxx) #code hier

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %% [markdown]
# ## Lösung

# %%
# Gib einen sinnvollen und erlaubten Wert bei "xxxx" ein und erkläre, wie der Wert das Resultat beinflusst.

class DQN(nn.Module):
    def __init__(self, n_observations, n_actions):
        super(DQN, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 512)
        self.layer3 = NoisyLinear(512, n_actions, sigma_init=xxxx  0.1) #code hier   # sigma_init ist kein korrekter Parameter. Falls std_init gemeint ist, dann ist es die Startwert der Standardabweichung für das Rauaschen, welches zu den Gewichten hinzugefügt wird. Wir nehmen 0.1 (default Wert)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %% [markdown]
# ## Aufgabe 1.4

# %%
#Aufgabe
# i) Vervollständigen sie die fehlenden Werte
# ii) Berechnen sie die Anzahl trainable Parameter

data = torch.rand((1000, 6))

var = # hier code

class FCN(nn.Module):
  def __init__(self):
    super(FCN, self).__init__()
    self.net = nn.Sequential(
        nn.LazyLinear(out_features=var), ##
        nn.ReLU(),
        nn.Linear(in_features=8, out_features=16, bias=False),
        nn.ReLU()
    )

  def forward(self, x):
    return self.net(x)

model = FCN()
model.forward(data)

# %% [markdown]
# ## Lösung

# %%
#Aufgabe
# i) Vervollständigen sie die fehlenden Werte
# ii) Berechnen sie die Anzahl trainable Parameter

data = torch.rand((1000, 6))

var = 8 # hier code  = in_features von Layer 2

class FCN(nn.Module):
  def __init__(self):
    super(FCN, self).__init__()
    self.net = nn.Sequential(
        nn.LazyLinear(out_features=var), ##
        nn.ReLU(),
        nn.Linear(in_features=8, out_features=16, bias=False),
        nn.ReLU()
    )

  def forward(self, x):
    return self.net(x)

model = FCN()
model.forward(data)


# Trainable Parameters
# Layer 1: 6 x 8  =  48
# Layer 1 Bias:   =   8
# Layer 2: 8 x 16 = 128
# Layer 2 Bias    =   0
# ---------------------
# Total:            184
# Out:
# tensor([[0.0000, 0.0000, 0.0672,  ..., 0.2655, 0.0000, 0.0051],
#         [0.0000, 0.0000, 0.1336,  ..., 0.4282, 0.0000, 0.0000],
#         [0.0000, 0.0827, 0.0138,  ..., 0.2766, 0.0000, 0.0000],
#         ...,
#         [0.0000, 0.0667, 0.0202,  ..., 0.2882, 0.0000, 0.0000],
#         [0.0000, 0.1089, 0.1254,  ..., 0.4491, 0.0000, 0.0486],
#         [0.0000, 0.0851, 0.1371,  ..., 0.5758, 0.0000, 0.0734]],
#        grad_fn=<ReluBackward0>)

# %% [markdown]
# ## Aufgabe 1.5

# %%
class CustomNetwork(nn.Module):
    def __init__(self, input_dim, output_dim, dropout_prob=0.3):
        super().__init__()

        # Define layers
        self.fc1 = nn.Linear(...)  # Define the parameter(s)
        self.bn1 = nn.BatchNorm1d(...)  # Define the parameter(s)
        self.dropout1 = nn.Dropout(dropout_prob)

        self.fc2 = nn.Linear(...)  # Define the parameter(s)
        self.bn2 = nn.BatchNorm1d(...)  # Define the parameter(s)
        self.dropout2 = nn.Dropout(dropout_prob)

        self.fc3 = nn.Linear(...)  # Define the parameter(s)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.activation(self.bn1(self.fc1(x)))
        x = self.dropout1(x)
        x = self.activation(self.bn2(self.fc2(x)))
        x = self.dropout2(x)
        return self.fc3(x)

# Example usage:
input_dim = 256  # Example input size
output_dim = 3  # Example output size

# TODO: Instantiate the network with the correct layer sizes
model = CustomNetwork(input_dim, output_dim)

# Print model summary
print(model)

# %% [markdown]
# ## Lösung

# %%
class CustomNetwork(nn.Module):
    def __init__(self, input_dim, output_dim, dropout_prob=0.3):
        super().__init__()

        # Define layers
        self.fc1 = nn.Linear(input_dim, 32)  # Define the parameter(s)
        self.bn1 = nn.BatchNorm1d(32)  # Define the parameter(s)
        self.dropout1 = nn.Dropout(dropout_prob)

        self.fc2 = nn.Linear(32, 64)  # Define the parameter(s)
        self.bn2 = nn.BatchNorm1d(64)  # Define the parameter(s)
        self.dropout2 = nn.Dropout(dropout_prob)

        self.fc3 = nn.Linear(64, output_dim)  # Define the parameter(s)
        self.activation = nn.ReLU()

    def forward(self, x):
        x = self.activation(self.bn1(self.fc1(x)))
        x = self.dropout1(x)
        x = self.activation(self.bn2(self.fc2(x)))
        x = self.dropout2(x)
        return self.fc3(x)

# Example usage:
input_dim = 256  # Example input size
output_dim = 3  # Example output size

# TODO: Instantiate the network with the correct layer sizes
model = CustomNetwork(input_dim, output_dim)

# Print model summary
print(model)
model(torch.rand(100, 256))
# Out:
# CustomNetwork(
#   (fc1): Linear(in_features=256, out_features=32, bias=True)
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (bn2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=64, out_features=3, bias=True)
#   (activation): ReLU()
# )
# tensor([[-0.3494,  0.1340,  0.2594],
#         [-0.0944,  0.3434,  0.2772],
#         [-0.4034,  0.0651,  0.0514],
#         [ 0.3240,  0.2200, -0.7682],
#         [-0.0414,  0.5945,  0.5581],
#         [ 0.3415,  0.0611, -0.7458],
#         [ 0.0840,  0.6150, -0.0275],
#         [-0.4135, -0.0456, -0.1934],
#         [-0.7703, -0.2257, -0.6958],
#         [ 0.3069,  0.0255,  0.0343],
#         [-0.2680,  1.0154,  0.3144],
#         [ 0.5214,  0.2956, -0.3140],
#         [-0.7871, -0.0353,  0.2209],
#         [-0.8837, -0.7214,  0.2339],
#         [-0.9833,  0.1919, -0.1469],
#         [-0.2047,  0.4050, -0.1494],
#         [-0.4548,  0.1451,  0.0032],
#         [ 0.0906, -1.2111, -0.2577],
#         [-0.8634, -0.5000,  0.2030],
#         [-0.3210,  0.0965,  0.1454],
#         [-0.1236, -0.0422, -0.2730],
#         [-0.7291,  0.8443, -0.3668],
#         [-0.0183, -0.0027,  0.1975],
#         [ 0.0260,  0.5767,  0.1006],
#         [-0.4000, -0.1550, -0.0933],
#         [-0.4292,  0.0163, -0.6744],
#         [-0.0086,  0.1714, -0.1038],
#         [-0.2833,  0.1818, -0.2581],
#         [ 0.6361, -0.3466, -0.2783],
#         [-0.2001,  0.0658, -0.2967],
#         [-0.1832, -0.0593, -0.0777],
#         [ 0.0664,  0.6604, -0.2854],
#         [-0.3950,  0.3604, -0.3324],
#         [-0.4544,  0.7358, -0.5495],
#         [ 0.0554, -0.0720, -0.3557],
#         [-0.2273,  0.0382,  0.3302],
#         [-0.2348, -0.2330,  0.4653],
#         [-1.0808, -0.1650,  0.0201],
#         [-0.8094, -0.3803, -0.1222],
#         [-0.0159, -0.6585, -0.2211],
#         [-0.5073,  0.2924, -0.2789],
#         [-0.2412, -0.3492, -0.6312],
#         [-0.0585,  0.9975, -0.6492],
#         [ 0.0913,  0.0562, -0.1360],
#         [-0.0137,  0.4941,  0.5106],
#         [ 0.8828,  0.1687, -0.7117],
#         [-0.3362,  0.3004, -0.3708],
#         [-0.5795,  0.3145, -0.0164],
#         [-0.2355,  0.5189, -0.0945],
#         [ 0.3986,  0.1194,  0.6393],
#         [-1.1192,  1.5974, -0.8938],
#         [ 0.4554,  0.0999,  0.0386],
#         [ 0.5237,  0.3800, -0.0214],
#         [ 0.0128,  0.4932, -0.2926],
#         [ 0.3828,  0.5014, -0.0345],
#         [-0.6447,  0.8553,  1.1210],
#         [-0.1160,  0.3186, -0.6698],
#         [-0.7645, -0.0821, -0.1467],
#         [ 0.2441, -0.5955,  0.1257],
#         [-0.1415,  0.1996, -0.4118],
#         [ 0.1808,  0.1275, -0.1695],
#         [-0.3351,  0.3931, -0.0989],
#         [-0.5644,  0.2028, -0.7950],
#         [ 0.4023,  0.2360, -0.1209],
#         [-0.1266,  0.9109,  0.4348],
#         [-0.4328,  0.2130, -0.4359],
#         [-0.6672,  0.2962, -0.1893],
#         [-0.2805, -0.1759, -0.4005],
#         [-0.3122,  1.1321,  0.1275],
#         [-0.4225,  0.3062, -0.4509],
#         [-0.9402, -0.0393,  0.2178],
#         [-0.2192,  0.3529, -0.2308],
#         [-0.2496,  0.1195,  0.1988],
#         [-0.5306,  0.2714, -0.0444],
#         [ 0.9485,  0.5097,  0.2870],
#         [-0.8774,  0.0220, -0.5325],
#         [-0.1643,  0.1818, -0.3212],
#         [-0.2951,  0.0466, -0.0698],
#         [-0.6737, -0.2459, -0.5002],
#         [-0.1915,  0.1695, -0.1669],
#         [-0.1483, -0.0192, -0.2597],
#         [-0.2616,  0.1156, -0.0278],
#         [ 0.0047, -0.4934, -0.5436],
#         [-0.4034, -0.0959,  0.0463],
#         [-0.3645,  0.9700,  0.1879],
#         [ 0.0074,  0.6199, -0.4782],
#         [-0.2856, -0.2260, -0.1135],
#         [-0.7862, -0.5363, -0.4844],
#         [-0.3275, -0.0115, -0.0525],
#         [ 0.1240, -0.1975,  0.0357],
#         [ 0.3827,  0.5139, -0.0937],
#         [-0.0280,  0.2306,  0.1096],
#         [ 0.1599,  0.6001,  0.0259],
#         [-1.5826,  0.3846, -0.4636],
#         [ 0.5002, -0.4285, -0.7555],
#         [-0.3277, -0.1298,  0.0332],
#         [-0.2654,  0.3949,  0.2373],
#         [-0.0782, -0.1854,  0.2194],
#         [ 0.2630,  0.2722, -0.8173],
#         [ 0.2639, -0.5920, -0.5228]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# Wir definieren folgende **trainierbare Netzwerkparameter**:

# %% [markdown]
# ### 2 - Team 2 Vervollständigen Sie bitte den Code und bestimmen Sie: **18 Punkte**
#
# 1. Vervollständigen Sie bitte den Code an den **fünf (5)** Stellen: missing 1, 2, 3, 4, 5 - **10 Punkte**
# > Beachten Sie dabei, dass:
# > - Zuerst werden die Conv. Layer durchlaufen, anschliessend die Linearen Layer
# > - Die Datensatz-Länge ist frei wählbar (jedoch nicht die Anzahl der Spalten/Variablen)
# 2. Nachdem Sie fehlende Grössen eingefügt haben, können Sie jetzt die Anzahl der trainable Parameter pro Layer bestimmen - **8 Punkte**

# %% [markdown]
# Gegeben sind 4 Images **unterscheidlicher Grösse**

# %%
class NeuronalNet(nn.Module):
    def __init__(self) -> None:
        super(NeuronalNet, self).__init__()

        # 3 channel input, 6 channel output, size of 5x5x tiles => will result in shape 28x28 shape
        self.conv1 = nn.Conv2d("input value here", "input value here", 5)

        # 2 x 2 tiles with Stride of 2 will result in shape 14 x 14
        self.pool = nn.MaxPool2d(2, 2)

        # 6 channel input, 16 channel output, size of 5x5x tiles => will result in shape 10x10 shape
        self.conv2 = nn.Conv2d(6, "input value here", 5)

        self.fc1 = nn.Linear(25, 120)
        self.fc2 = nn.Linear("input value here", 84)
        self.fc3 = nn.Linear("input value here", 10)


    def forward(self, x):
        logits = self.pool(F.relu(self.conv1(x)))
        logits = self.pool(F.relu(self.conv2(logits)))

        logits = torch.flatten(logits, 1) # flatten all dimensions except batch
        logits = F.relu(self.fc1(logits))
        logits = F.relu(self.fc2(logits))
        logits = self.fc3(logits)
        return logits

net = NeuronalNet()

Image = torch.rand((3, 32, 32))
Image

logits = net(Image)
logits.shape

# %% [markdown]
# ## Lösung

# %%
import torch.nn.functional as F
class NeuronalNet(nn.Module):
    def __init__(self) -> None:
        super(NeuronalNet, self).__init__()

        # 3 channel input, 6 channel output, size of 5x5x tiles => will result in shape 28x28 shape
        self.conv1 = nn.Conv2d(3, 6, 5)

        # 2 x 2 tiles with Stride of 2 will result in shape 14 x 14
        self.pool = nn.MaxPool2d(2, 2)

        # 6 channel input, 16 channel output, size of 5x5x tiles => will result in shape 10x10 shape
        self.conv2 = nn.Conv2d(6, 16, 5)

        self.fc1 = nn.Linear(25, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)


    def forward(self, x):
        logits = self.pool(F.relu(self.conv1(x)))
        logits = self.pool(F.relu(self.conv2(logits)))

        logits = torch.flatten(logits, 1) # flatten all dimensions except batch
        logits = F.relu(self.fc1(logits))
        logits = F.relu(self.fc2(logits))
        logits = self.fc3(logits)
        return logits

net = NeuronalNet()

Image = torch.rand((3, 32, 32))
print("Image shape:", Image.shape)

logits = net(Image)
print("logits shape:", logits.shape)
# Out:
# Image shape: torch.Size([3, 32, 32])
# logits shape: torch.Size([16, 10])

# %% [markdown]
# ### 1.2 Sie wollen ein **Dense-Network** erstellen, das auf solchen unterschiedlich grossen Bildern trainiert werden kann **12 Punkte**
# 1. Ergänzen Sie die fehlenden Code-Zeilen **10 Punkte**
# 2. Bestimmen Sie das Output-Shape des Netzwerks **2 Punkte** -> Network Output shape:  {torch.Size([1, 10])}

# %% [markdown]
# ## 3 - Team 3 Deep Reinforcement Learning - Fehler Suche **50 Punkte**
#
# **Aufgabenstellung**: Fehler in der Rock-Paper-Scissors-Environment finden und beheben.
# Diese Vorlage enthält eine fehlerhafte Implementierung einer Rock-Paper-Scissors-Umgebung für ein Deep Reinforcement Learning (DRL)-Modell mit TorchRL.
# Eure Aufgabe ist es, die Fehler zu finden und zu beheben, damit das Modell korrekt funktioniert.
#
# ---

# %%
# !pip install --upgrade torchrl
# Out:
# Collecting torchrl
#   Downloading torchrl-0.7.2-cp311-cp311-manylinux1_x86_64.whl.metadata (39 kB)
# Requirement already satisfied: torch>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from torchrl) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchrl) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from torchrl) (24.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from torchrl) (3.1.1)
# Collecting tensordict>=0.7.0 (from torchrl)
#   Downloading tensordict-0.7.2-cp311-cp311-manylinux1_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from tensordict>=0.7.0->torchrl) (3.10.15)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.6.0->torchrl)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.6.0->torchrl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.6.0->torchrl) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.6.0->torchrl) (3.0.2)
# Downloading torchrl-0.7.2-cp311-cp311-manylinux1_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.0 MB/s eta 0:00:00
# Downloading tensordict-0.7.2-cp311-cp311-manylinux1_x86_64.whl (400 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 kB 21.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 53.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 857.0 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, tensordict, torchrl
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 tensordict-0.7.2 torchrl-0.7.2

# %%
# Imports
from typing import Optional

import pandas as pd
import numpy as np

import torch
from torch.optim import Adam

from tensordict import TensorDict, TensorDictBase
from tensordict.nn import TensorDictModule, TensorDictSequential

from torchrl.modules import EGreedyModule, MLP, QValueModule
from torchrl.data import OneHot, Composite, UnboundedContinuous, Categorical, Unbounded
from torchrl.collectors import SyncDataCollector
from torchrl.objectives import DQNLoss, SoftUpdate
from torchrl.envs import EnvBase, StepCounter, TransformedEnv, step_mdp
from torchrl.envs.utils import check_env_specs
from torchrl.data.replay_buffers import ReplayBuffer
from torchrl.data.replay_buffers.storages import LazyTensorStorage

# %%
# Aktionen und Rewards definieren
ACTIONS = {0: "Schere", 1: "Stein", 2: "Papier"}
REWARDS = {
    (0, 0): 0, (0, 1): -1, (0, 2): 1,
    (1, 0): 1, (1, 1): 0, (1, 2): -1,
    (2, 0): -1, (2, 1): 1, (2, 2): 0
}
RANDOM = np.random.default_rng(42)
def generate_random_moves(num_samples=1000):
    data = {
        # Unser Gegner hat leichten Hang zur Schere ;-)
        "move": RANDOM.choice([0, 1, 2], size=num_samples, p=[0.4, 0.3, 0.3])
    }
    return pd.DataFrame(data)

class RockPaperScissorsEnv(EnvBase):
    def __init__(self, device="cpu"):
        super().__init__(device=device)
        self.dataset = generate_random_moves()
        self.num_features = 1
        self.observation_spec = Composite(observation=Unbounded(shape=(1,), dtype=torch.float32))
        self.action_spec = Composite(action=OneHot(n=len(ACTIONS.items()), dtype=torch.int64))
        self.reward_spec = Composite(reward=Unbounded(shape=(1,), dtype=torch.float32))

    def _step(self,tensordict):
        action = tensordict["action"].argmax(dim=-1).item()
        next_sample = self.dataset.sample(1).iloc[0]
        next_state = torch.tensor(
            # next_sample["move"].astype(np.float32),                    # Fix Roger
            [next_sample["move"].astype(np.float32)],                    # Fix Roger
            dtype=torch.float32
        )
        opponent_action = torch.randint(0, 3, (1,)).item()  # Zufälliger Gegner
        reward = REWARDS[(action, next_sample["move"].astype(np.float32))]
        return TensorDict({
            "observation": next_state,
            #"success": torch.tensor([reward], dtype=torch.float32),      # Fix Roger
            "reward": torch.tensor([reward], dtype=torch.float32),        # Fix Roger
            "done": torch.tensor(False, dtype=torch.bool)
            #"action_value": action                                       # Fix Roger
      })

    def _reset(self, tensordict=None):
        sample = self.dataset.sample(1).iloc[0]
        print(f"Sample {sample}")
        # Get the value from the 'move' column of the first row
        #state = torch.tensor(sample["move"], dtype=torch.float32)       # Fix Roger
        state = torch.tensor([sample["move"]], dtype=torch.float32)      # Fix Roger

        return TensorDict({
            "observation": torch.tensor([state], dtype=torch.float32),
            "done": torch.tensor(False, dtype=torch.bool),  # Explicit shape [1]
        }, batch_size=[])


    def _set_seed(self, seed: Optional[int]):
        pass

# %%
env = RockPaperScissorsEnv()

value_mlp = MLP(in_features=env.num_features, out_features=env.action_spec.shape[-1], num_cells=[64, 64])
value_net = TensorDictModule(value_mlp, in_keys=["observation"], out_keys=["action_value"])
policy = TensorDictSequential(value_net, QValueModule(spec=env.action_spec))
exploration_module = EGreedyModule(
    env.action_spec, annealing_num_steps=10_000, eps_init=0.9
)
policy_explore = TensorDictSequential(policy, exploration_module)

# %%
def create_env():
  return TransformedEnv(RockPaperScissorsEnv(), StepCounter(max_steps=1_000))

# %%
init_rand_steps = 500
collector = SyncDataCollector(
    create_env_fn = create_env,
    policy = policy_explore,
    frames_per_batch=1,  # ✅ Match the batch size
    total_frames=1_000,
    init_random_frames=init_rand_steps,
    storing_device="cpu",  # ✅ Ensure storing happens on CPU
    split_trajs=False,  # ✅ Prevent trajectory splitting from dropping keys
    exploration_type="mode"
)
rb = ReplayBuffer(storage=LazyTensorStorage(100_000))
loss = DQNLoss(value_network=policy, action_space=env.action_spec, delay_value=True)
optim = Adam(loss.parameters(), lr=0.02)
updater = SoftUpdate(loss, eps=0.99)
# Out:
# Sample move    2
# Name: 504, dtype: int64

# %%
# Roger
check_env_specs(env)
# Out:
# 2025-03-18 15:18:08,346 [torchrl][INFO] check_env_specs succeeded!
# Sample move    0
# Name: 680, dtype: int64

# %%
import time
total_count = 0
total_episodes = 0
optim_steps = 1
t0 = time.time()
for i, data in enumerate(collector):
    # Write data in replay buffer
    #print(data)
    rb.extend(data)
    max_length = rb[:]["next", "step_count"].max()
    #print("max_length", max_length)
    if len(rb) > init_rand_steps:
        # Optim loop (we do several optim steps
        # per batch collected for efficiency)
        for _ in range(optim_steps):
            sample = rb.sample(100)
            loss_vals = loss(sample)
            #print("loss function is called:", loss_vals)
            loss_vals["loss"].backward()
            optim.step()
            optim.zero_grad()
            # Update exploration factor
            exploration_module.step(data.numel())
            # Update target params
            updater.step()
            #if i % 10:
            #    print(f"Max num steps: {max_length}, rb length {len(rb)}")
            total_count += data.numel()
            total_episodes += data["next", "done"].sum()
        #if max_length > 200:
        #    break

t1 = time.time()

print(
    f"solved after {total_count} steps, {total_episodes} episodes and in {t1-t0}s."
)
# Out:
# Sample move    0
# Name: 899, dtype: int64
# solved after 500 steps, 1 episodes and in 6.813915967941284s.

# %% [markdown]
# ## Lösung

# %% [markdown]
# Check for
# ````
# # Fix Roger
# ````
# in the code above

# %%
print("Good Luck!")
